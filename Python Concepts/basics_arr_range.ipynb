# %%
import inventorize

# %%
prime_numbers=[1,3,5,7,11,13,17]

# %%
prime_numbers=2

# %%
prime_numbers=[1,3,5,7,11,13,17]

# %%
prime_numbers=[2]

# %%
prime_numbers=[1,3,5,7,11,13,17]

# %%
prime_numbers[3]
# Out:
# 7

# %%
prime_numbers[:5]
# Out:
# [1, 3, 5, 7, 11]

# %%
prime_numbers[3:]
# Out:
# [7, 11, 13, 17]

# %%
prime_numbers=[1,3,5,7,11,13,17]

# %%
prime_numbers[3:]
# Out:
# [7, 11, 13, 17]

# %%
Products_list=['Shampoo','hair oil','face masks',"lip balm","lipstick","talc"]

# %%
Products_list[4]
# Out:
# 'lipstick'

# %%
class_dict={'Pranay':'Male','Aman':'Male','Nayanshi':'Female','Sanjay':'Male','Poonam': 'Female'}

# %%
class_dict
# Out:
# {'Pranay': 'Male',
#  'Aman': 'Male',
#  'Nayanshi': 'Female',
#  'Sanjay': 'Male',
#  'Poonam': 'Female'}

# %%
class_dict.keys()
# Out:
# dict_keys(['Pranay', 'Aman', 'Nayanshi', 'Sanjay', 'Poonam'])

# %%
class_dict.values()
# Out:
# dict_values(['Male', 'Male', 'Female', 'Male', 'Female'])

# %%
class_dict['Pranay']
# Out:
# 'Male'

# %%
class_dict['Aman']
# Out:
# 'Male'

# %%
class_dict.get('Aman')
# Out:
# 'Male'

# %%
import pandas as pd

# %%
demo_data=pd.read_csv('pakistan_economic_indicators_2000_2025.csv')

# %%
demo_data
# Out:
#     year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  inflation_cpi_pct  \
# 0   2000        99.9            3.90                 624                4.4
# 1   2001       101.4            2.00                 614                3.1
# 2   2002       107.6            3.10                 628                3.5
# 3   2003       116.3            4.70                 657                3.1
# 4   2004       126.7            7.40                 697                7.4
# 5   2005       137.4            9.00                 736                9.3
# 6   2006       152.4            5.80                 795                7.9
# 7   2007       168.0            6.80                 855                7.6
# 8   2008       192.5            5.00                 956               12.0
# 9   2009       173.6            2.60                 843               20.8
# 10  2010       177.1            1.60                 843               11.7
# ...

# %%
demo_data.head()
# Out:
#    year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  inflation_cpi_pct  \
# 0  2000        99.9             3.9                 624                4.4
# 1  2001       101.4             2.0                 614                3.1
# 2  2002       107.6             3.1                 628                3.5
# 3  2003       116.3             4.7                 657                3.1
# 4  2004       126.7             7.4                 697                7.4
#
#    unemployment_pct  remittances_usd_bn  exports_usd_bn  imports_usd_bn  \
# 0               7.8                1.08             9.2            10.3
# 1               7.8                1.46             9.8            10.3
# 2               8.3                2.39            10.0            10.9
# 3               8.3                3.96            11.7            12.2
# 4               7.7                3.87            14.0            15.5
#
#    trade_balance_usd_bn  ...  mobile_per_100  imf_program_active  \
# ...

# %%
demo_data.tail()
# Out:
#     year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  inflation_cpi_pct  \
# 21  2021       348.7            5.70                1315                8.9
# 22  2022       376.5            6.10                1393               12.2
# 23  2023       337.9           -0.04                1237               29.2
# 24  2024       374.6            2.40                1353               23.4
# 25  2025       390.0            3.00                1390                7.2
#
#     unemployment_pct  remittances_usd_bn  exports_usd_bn  imports_usd_bn  \
# 21               6.3               31.10            31.8            72.7
# 22               6.2               27.02            32.4            80.0
# 23               6.5               26.10            27.7            55.3
# 24               6.4               34.60            31.0            53.2
# 25               5.4               38.00            34.0            58.0
#
#     trade_balance_usd_bn  ...  mobile_per_100  imf_program_active  \
# ...

# %%
demo_data.shape
# Out:
# (26, 32)

# %%
demo_data.describe()
# Out:
#               year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  \
# count    26.000000   26.000000       26.000000           26.000000
# mean   2012.500000  233.084615        4.110000         1012.153846
# std       7.648529   92.279119        2.195969          258.434161
# min    2000.000000   99.900000       -0.500000          614.000000
# 25%    2006.250000  156.300000        2.700000          807.000000
# 50%    2012.500000  243.350000        4.100000         1040.500000
# 75%    2018.750000  299.375000        5.650000         1226.000000
# max    2025.000000  390.000000        9.000000         1393.000000
#
#        inflation_cpi_pct  unemployment_pct  remittances_usd_bn  \
# count          26.000000         26.000000           26.000000
# mean            9.361538          6.261538           14.866538
# std             6.431739          1.059085           10.775681
# min             2.900000          4.500000            1.080000
# ...

# %%
demo_data.unemployment_pct.describe()
# Out:
# count    26.000000
# mean      6.261538
# std       1.059085
# min       4.500000
# 25%       5.650000
# 50%       6.000000
# 75%       6.475000
# max       8.300000
# Name: unemployment_pct, dtype: float64

# %%
demo_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    26 non-null     int64
#  1   gdp_usd_bn              26 non-null     float64
#  2   gdp_growth_pct          26 non-null     float64
#  3   gdp_per_capita_usd      26 non-null     int64
#  4   inflation_cpi_pct       26 non-null     float64
#  5   unemployment_pct        26 non-null     float64
#  6   remittances_usd_bn      26 non-null     float64
#  7   exports_usd_bn          26 non-null     float64
#  8   imports_usd_bn          26 non-null     float64
#  9   trade_balance_usd_bn    26 non-null     float64
#  10  forex_reserves_usd_bn   26 non-null     float64
#  11  policy_rate_pct         26 non-null     float64
#  12  pkr_per_usd             26 non-null     float64
#  13  public_debt_gdp_pct     26 non-null     float64
# ...

# %%
first_five=demo_data.iloc[1:5,1:5]

# %%
first_five
# Out:
#    gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  inflation_cpi_pct
# 1       101.4             2.0                 614                3.1
# 2       107.6             3.1                 628                3.5
# 3       116.3             4.7                 657                3.1
# 4       126.7             7.4                 697                7.4

# %%
two_column= demo_data.loc[:,['gdp_usd_bn','gdp_per_capita_usd']]
two_column
# Out:
#     gdp_usd_bn  gdp_per_capita_usd
# 0         99.9                 624
# 1        101.4                 614
# 2        107.6                 628
# 3        116.3                 657
# 4        126.7                 697
# 5        137.4                 736
# 6        152.4                 795
# 7        168.0                 855
# 8        192.5                 956
# 9        173.6                 843
# 10       177.1                 843
# 11       222.2                1043
# 12       239.6                1097
# 13       247.1                1109
# 14       270.6                1193
# 15       271.1                1168
# 16       282.5                1190
# 17       305.0                1258
# 18       314.6                1268
# 19       263.7                1038
# 20       263.2                1016
# 21       348.7                1315
# 22       376.5                1393
# 23       337.9                1237
# 24       374.6                1353
# 25       390.0                1390

# %%
second_subset= demo_data.iloc[[1,2,3],[1,2,3]]
second_subset
# Out:
#    gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd
# 1       101.4             2.0                 614
# 2       107.6             3.1                 628
# 3       116.3             4.7                 657

# %%
demo_data.columns
# Out:
# Index(['year', 'gdp_usd_bn', 'gdp_growth_pct', 'gdp_per_capita_usd',
#        'inflation_cpi_pct', 'unemployment_pct', 'remittances_usd_bn',
#        'exports_usd_bn', 'imports_usd_bn', 'trade_balance_usd_bn',
#        'forex_reserves_usd_bn', 'policy_rate_pct', 'pkr_per_usd',
#        'public_debt_gdp_pct', 'current_account_usd_bn', 'fdi_inflows_usd_bn',
#        'population_mn', 'literacy_rate_pct', 'agriculture_gdp_pct',
#        'services_gdp_pct', 'industry_gdp_pct', 'tax_revenue_gdp_pct',
#        'mobile_per_100', 'imf_program_active', 'key_events',
#        'remittances_gdp_pct', 'exports_gdp_pct', 'imports_gdp_pct',
#        'fdi_gdp_pct', 'gdp_growth_category', 'inflation_category', 'decade'],
#       dtype='str')

# %%
demo_data['Demo_class']= demo_data['gdp_growth_pct']*10

# %%
demo_data
# Out:
#     year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  inflation_cpi_pct  \
# 0   2000        99.9            3.90                 624                4.4
# 1   2001       101.4            2.00                 614                3.1
# 2   2002       107.6            3.10                 628                3.5
# 3   2003       116.3            4.70                 657                3.1
# 4   2004       126.7            7.40                 697                7.4
# 5   2005       137.4            9.00                 736                9.3
# 6   2006       152.4            5.80                 795                7.9
# 7   2007       168.0            6.80                 855                7.6
# 8   2008       192.5            5.00                 956               12.0
# 9   2009       173.6            2.60                 843               20.8
# 10  2010       177.1            1.60                 843               11.7
# ...
