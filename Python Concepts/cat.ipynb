# %%
cat = ('''_                        
                      \`*-.                    
                       )  _`-.                 
                      .  : `. .                
                      : _   '  \               
                      ; *` _.   `*-._          
                      `-.-'          `-.       
                        ;       `       `.     
                        :.       .        \    
                        . \  .   :   .-'   .   
                        '  `+.;  ;  '      :   
                        :  '  |    ;       ;-. 
                        ; '   : :`-:     _.`* ;
               [bug] .*' /  .*' ; .*`- +'  `*' 
                     `*-*   `*-*  `*-*'            ''' )
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\`'
# <>:2: SyntaxWarning: invalid escape sequence '\`'
# /var/folders/40/ly4n03nn71n6f5x_5z8f38600000gn/T/ipykernel_40135/1606896058.py:2: SyntaxWarning: invalid escape sequence '\`'
#   \`*-.

# %%
print(cat)
# Out:
# _
#                       \`*-.
#                        )  _`-.
#                       .  : `. .
#                       : _   '  \
#                       ; *` _.   `*-._
#                       `-.-'          `-.
#                         ;       `       `.
#                         :.       .        \
#                         . \  .   :   .-'   .
#                         '  `+.;  ;  '      :
#                         :  '  |    ;       ;-.
#                         ; '   : :`-:     _.`* ;
#                [bug] .*' /  .*' ; .*`- +'  `*'
#                      `*-*   `*-*  `*-*'
