# %%
a = 33
b = 200
if b > a: print("b is greater than a")     # If statement, without indentation (will raise an error):
# Out:
# b is greater than a

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
age = int(input("Please! enter your age. "))
license = str(input ("Please! Verify Do you have License Y/N ?"))

if age >= 18:
    print("You can drive")
 
    if license.lower() == "y":
       print ("Great!")
    else: 
       print ("Get one as soon as possible.")
else:
    print("You are too young to drive")
# Out:
# Please! enter your age.  28
# Please! Verify Do you have License Y/N ? y
# You can drive
# Great!
