# %%
def myfunc():
   global x
x = "fantastic"
print(x)
# Out:
# fantastic

# %%
x = "Easy"

def myfunc():
  x = "Learnable"
  print("Python is " + x)      #1
  
  x = "Awesome"          
  print("Python is " + x)      #2

myfunc()

print("Python is " + x)        #3
x = "Super"
print("Python is " + x)        #4
# Out:
# Python is Learnable
# Python is Awesome
# Python is Easy
# Python is Super

# %%
x = 'awesome'
def myfunc():
  x = 'fantastic'
myfunc()
print('Python is ' + x)
# Out:
# Python is awesome

# %%
x = 'awesome'
def myfunc():
    global x
    x = 'fantastic'
myfunc()
print('Python is ' + x)
# Out:
# Python is fantastic

# %%
x = 4
x = str("Sun")
y = "Pranay"
z = ("Moon")
print(x ,y ,z)
print("x","y","z")
print(str(x),str(y),str(z))
print(str("x"),str("y"),str("z"))
# Out:
# Sun Pranay Moon
# x y z
# Sun Pranay Moon
# x y z

# %%
x, y, z = "Pranay", "is", "Awesome"

print(x)
print(y)
print(z)
print("x")
print("y")
print("z")
print(str(x))
print(str(y))
print(str(z))
print(str("x"))
print(str("y"))
print(str("z"))
# Out:
# Pranay
# is
# Awesome
# x
# y
# z
# Pranay
# is
# Awesome
# x
# y
# z

# %%
fruits = ['apple', 'banana', 'cherry']
a, b, c = fruits
print(a)
# Out:
# apple
