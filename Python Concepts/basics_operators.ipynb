# %%
sum1 = 100 + 50      # 150 (100 + 50)
print(sum1)
sum2 = sum1 + 250    # 400 (150 + 250)
print(sum2)
sum3 = sum2 + sum2   # 800 (400 + 400)
print(sum3)
# Out:
# 150
# 400
# 800

# %%
x = 15
y = 4

print(x + y)
print(x - y)
print(x * y)
print(x / y)       #/ - Division (returns a float) 
print(x % y)
print(x ** y)      #15^4
print(x // y)      # // - Floor division (returns an integer)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %%
x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 5

print(1 < x < 10)

print(1 < x and x < 10)
# Out:
# True
# True

# %%
x = 5

print(x > 0 and x < 10)                 #	Returns True if both statements are true
print(x < 5 or x > 10)                  #   Returns True if one of the statements is true
print(not(x > 3 and x < 10))            #   Reverse the result, returns False if the result is true
# Out:
# True
# False
# False

# %%
x = ["apple", "banana"]             # is checks identity, not content.
y = ["apple", "banana"]
z = x
x = y
print(x is z)               # Returns True if both variables are the same object
print(x is not y)           # Returns True if both variables are not the same object
print(x == y)
# Out:
# False
# False
# True

# %%
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)           # The word in checks whether something exists inside a collection.
# Out:
# True

# %%
fruits = ["apple", "banana", "cherry"]       # in → does it exist inside?    #not in → does it NOT exist inside?

print("pineapple" not in fruits)
# Out:
# True

# %%
text = "Hello World"

print("H" in text)
print("hello" in text)
print("World" in text)
print("z" not in text)
# Out:
# True
# False
# True
# True

# %%
print(6 & 3)       # Bitwise operators is complicated for the moment
# Out:
# 2

# %%
#Operator precedence in Python determines which operation happens first when an expression has multiple operators.

#Parentheses > Powers > Multiply/Divide> Add/Subtract> Comparisons> Logical operators

#If two operators have the same precedence, the expression is evaluated from left to right.
