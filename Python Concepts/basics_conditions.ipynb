# %%
10+10
# Out:
# 20

# %%
print("Pranay- Supply Chain Manager")
# Out:
# Pranay- Supply Chain Manager

# %%
import numpy as np

# %%
np.array([4,5,6,7,8,9])
# Out:
# array([4, 5, 6, 7, 8, 9])

# %%
Pranay= 29
Aman=30
Shobhit=32
Akash=33
Karina=22
Boris=24
Katherin=40
Nannu=4

# %%
Pranay>40
# Out:
# False

# %%
(Pranay>20)&(Aman<=30)
# Out:
# True

# %%
def status(person):
    if (person>25):
        print('adult')
    elif(person>20):
        print('teenager')
    else : print('child')

# %%
status(Nannu)
# Out:
# child

# %%
class_list=[Pranay,Aman,Shobhit,Akash,Karina,Boris,Katherin,Nannu]

# %%
map_object=map(status,class_list)

# %%
status_list= list(map_object)
# Out:
# adult
# adult
# adult
# adult
# teenager
# teenager
# adult
# child
