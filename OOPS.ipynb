# %%
#OOP stands for Object-Oriented Programming.

#For example:  Class -- Car   Object- Volvo,Audi, Mahindra etc. 

#Python Classes/Objects

class Cars:
    def __init__(self):
        self.x = "Audi"
        self.y = "Mahindra"

car = Cars()

print(car.x)
print(car.y)
print("Which one you will buy?")
# Out:
# Audi
# Mahindra
# Which one you will buy?

# %%
class Car:
    def __init__(self, brand):      #The self parameter is a reference to the current instance of the class.
        self.brand = brand

car1 = Car("Audi")
car2 = Car("Mahindra")

print(car1.brand)
print(car2.brand)
# Out:
# Audi
# Mahindra

# %%
class MyClass:
    x=7

p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3.x)

#del p2

print(p2.x)
# Out:
# 7
# 7
# 7
# 7

# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand
    self.model = model
    self.year = year

  def display_info(self):
    print(f"{self.year} {self.brand} {self.model}")

car1 = Car("Toyota", "Corolla", 2020)
car1.display_info()

#It does not have to be named "self" , you can call it whatever you like, but it has to be the first parameter of any method in the class:
# Out:
# Hello, my name is Pranay I am  28 years old.
# Hello, my name is Aman I am  30 years old.
# Hello, my name is Shanvika I am  1 years old.

# %%
class Person:
  pass           # Without the __init__() method, you would need to set properties manually for each object:

p1 = Person()
p1.name = "Pranay"
p1.age = 28

print(p1.name)
print(p1.age)
# Out:
# Pranay
# 28

# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand
    self.model = model
    self.year = year

  def display_info(self):
    print(f"{self.year} {self.brand} {self.model}")

car1 = Car("Toyota", "Corolla", 2020)
car2 = Car("Mahindra", "XE90", 2025)

car1.display_info()
car2.display_info()
# Out:
# 2020 Toyota Corolla
# 2025 Mahindra XE90

# %%
class Personp:
  def __init__(self, name):
    self.name = name

  def greet(self):
    return "Hello, " + self.name

  def welcome(self):
    message = self.greet()
    print(message + "! Welcome to our website.")
name = input("What's your name?")
p1 = Personp(name)
p1.welcome()
# Out:
# What's your name? prana<
# Hello, prana<! Welcome to our website.
